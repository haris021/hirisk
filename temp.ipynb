# %%
import geopandas as gpd 

shapefile = gpd.read_file("HIMAP_boundaries/boundary_mountain_regions_hma_v3.shp")

# %%
shapefile.to_file("HIMAP_boundaries.geojson",river='GeoJSON')

# %%
shapefile.boundary.
# Out:
# C:\Users\User-PC\AppData\Local\Temp\ipykernel_28336\1757140322.py:1: UserWarning:
#
# Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
# 0      POINT (71.76583 35.78133)
# 1      POINT (76.40155 33.13975)
# 2      POINT (91.66512 28.20422)
# 3      POINT (83.32686 29.13594)
# 4      POINT (76.08351 35.81158)
# 5      POINT (72.48099 38.12644)
# 6      POINT (70.59197 39.50081)
# 7      POINT (76.19400 42.23132)
# 8      POINT (80.44889 45.01345)
# 9      POINT (79.73115 36.23727)
# 10     POINT (94.15922 29.62522)
# 11     POINT (84.09433 30.83028)
# 12    POINT (100.05789 29.97782)
# 13     POINT (85.78396 33.42169)
# 14     POINT (93.67972 32.58177)
# 15     POINT (97.40212 34.34276)
# 16     POINT (98.82020 37.93296)
# 17     POINT (90.96840 36.45282)
# 18     POINT (90.52404 38.77492)
# 19     POINT (87.77093 43.56018)
# 20     POINT (80.62027 41.87114)
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("HiAVALDB.csv")
df.loc[df["Type"] == "snow avalanches", "Type"] = "snow avalanche"
df.to_csv("HiAVALDB.csv", index = False)

# %%
import plotly.graph_objects as go
import pandas as pd

mapbox_access_token = "pk.eyJ1IjoiYW1hbnp5MTIzNCIsImEiOiJjbG9land0NjcwazR6MmtvMjgycTJ2bHp2In0.wEKHMlZHua7rHUV0Av03UQ"

df = pd.read_csv("HiAVALDB.csv", encoding = "latin1")
site_lat = df["Latitude"]
site_lon = df["Longitude"]
locations_name = df["Location"]

fig = go.Figure()

fig.add_trace(go.Scattermapbox(
        lat=df["Latitude"],
        lon=df["Longitude"],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=17,
            color='rgb(255, 0, 0)',
            opacity=0.7
        ),
        text=df["Location"],
        hoverinfo='text'
    ))

# fig.add_trace(go.Scattermapbox(
#         lat=site_lat,
#         lon=site_lon,
#         mode='markers',
#         marker=go.scattermapbox.Marker(
#             size=8,
#             color='rgb(242, 177, 172)',
#             opacity=0.7
#         ),
#         hoverinfo='none'
#     ))

fig.update_layout(
    title='Nuclear Waste Sites on Campus',
    autosize=True,
    hovermode='closest',
    showlegend=False,
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        
        pitch=0,
        zoom=3,
        style='light'
    ),
)

fig.show()

# %%
# Out:
#          minx       miny        maxx       maxy
# 0   68.710058  34.421565   74.653354  37.226381
# 1   72.777506  30.722099   80.370148  35.852196
# 2   87.989420  26.690150   95.449521  29.891531
# 3   76.880167  26.658831   89.275116  31.450370
# 4   72.443785  34.135254   79.706451  37.336899
# 5   69.401542  36.548695   75.187990  39.696972
# 6   66.752138  38.155370   74.641237  40.619788
# 7   69.723924  39.699777   83.066359  43.846566
# 8   78.180382  44.200968   82.468050  46.004881
# 9   75.908611  34.446577   83.956576  37.977726
# 10  89.590668  27.249427   97.881315  31.509423
# 11  78.657549  29.115747   90.185990  33.763137
# 12  95.350607  25.615122  105.014112  32.692721
# 13  78.101500  29.939665   92.126509  36.299911
# 14  90.075183  30.835393   97.348165  35.159973
# 15  91.411551  30.953058  102.613189  37.430094
# 16  93.708836  35.838573  103.939431  40.111719
# 17  83.626237  34.786887   98.673693  39.021147
# 18  85.351774  37.566988   95.610220  39.960441
# ...

# %%
for column in shapefile.bounds:
    print(column, min(shapefile.bounds[column]), max(shapefile.bounds[column]))
    # break
# Out:
# minx 66.75213761476203 95.35060707958624
# miny 25.61512158095887 44.20096756489906
# maxx 74.6412368552165 105.0141119492971
# maxy 29.89153110143185 46.00488116733804

# %%
import pandas as pd 
df = pd.read_csv("HMAGLOFDB (2).csv", encoding = "latin1")

# %%
import numpy as np

# %%
df["Lives_total"].str.replace('[^0-9]', '').replace('', np.nan).fillna(0).astype(int).sum()
# Out:
# C:\Users\User-PC\AppData\Local\Temp\ipykernel_15464\243704170.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["Lives_total"].str.replace('[^0-9]', '').replace('', np.nan).fillna(0).astype(int).sum()
# 6906

# %%
str("Total Injured: " + str(int(df["Injured_total"].replace('', np.nan).fillna(0).astype(int).sum())))
# Out:
# 'Total Injured: 20076'
